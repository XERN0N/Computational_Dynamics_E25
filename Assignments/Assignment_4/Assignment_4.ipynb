# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation, Slerp
from pyquaternion import Quaternion

# %%
l_b_1_wx = np.array([[1.0], [-0.1], [0.4]])
l_b_2_yz = np.array([[1.0], [0], [0.2]])

V_i_w = np.array([[1.2],[0.7],[0],[0.3],[0],[2.1]])

O_B2_B1 = np.array([[1/(2*np.sqrt(3))],[1/(2*np.sqrt(3))],[1/(2*np.sqrt(3))],[np.sqrt(3)/2]])
O_B1_I = np.array([[1/(2*np.sqrt(3))],[-1/(2*np.sqrt(3))],[1/(2*np.sqrt(3))],[np.sqrt(3)/2]])

R_B2_B1 = Quaternion(scalar=O_B2_B1[-1], vector=O_B2_B1[0:3]).rotation_matrix
R_B1_I = Quaternion(scalar=O_B1_I[-1], vector=O_B1_I[0:3]).rotation_matrix


"""
T_zw = np.eye(4)
T_zw[0:3,0:3] = R_B2_B1 #insert rotation matrix
T_zw[0:3,3] = l_b_2_yz.squeeze() #insert position at last column
l_b1_wz = l_b_1_wx+l_b_2_yz #Using 1.13
T_zw
"""
# Out:
# array([[ 0.66666667, -0.33333333,  0.66666667,  1.        ],
#        [ 0.66666667,  0.66666667, -0.33333333,  0.        ],
#        [-0.33333333,  0.66666667,  0.66666667,  0.2       ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])
