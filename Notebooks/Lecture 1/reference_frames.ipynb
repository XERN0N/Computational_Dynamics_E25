# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# asdasdasd

# %%
def global_pos_vec(global_pos, orientation_matrix, local_pos):
    """
    This funciton takes in the global position vector of a point

    """
    

    return global_position_vector
# Out:
#   Cell In[2], line 1
#     def global_position_vector
#                               ^
# SyntaxError: expected '('
